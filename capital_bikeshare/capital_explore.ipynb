# %%
import pandas as pd

# %% [markdown]
# The trip data is structured very differently from the citibike station data.
# I want to load in each line, and increment counters for checked out and checked in at those stations
# at those times. It seems to me that creating a series of times, and matching the in and out to those times
# would be straightforward.

# %%
temp = pd.DataFrame(pd.date_range('1/1/2011','1/2/2011',freq='H'),columns=['time'])
temp
# Out:
#                   time
# 0  2011-01-01 00:00:00
# 1  2011-01-01 01:00:00
# 2  2011-01-01 02:00:00
# 3  2011-01-01 03:00:00
# 4  2011-01-01 04:00:00
# 5  2011-01-01 05:00:00
# 6  2011-01-01 06:00:00
# 7  2011-01-01 07:00:00
# 8  2011-01-01 08:00:00
# 9  2011-01-01 09:00:00
# 10 2011-01-01 10:00:00
# 11 2011-01-01 11:00:00
# 12 2011-01-01 12:00:00
# 13 2011-01-01 13:00:00
# 14 2011-01-01 14:00:00
# 15 2011-01-01 15:00:00
# 16 2011-01-01 16:00:00
# 17 2011-01-01 17:00:00
# 18 2011-01-01 18:00:00
# 19 2011-01-01 19:00:00
# 20 2011-01-01 20:00:00
# 21 2011-01-01 21:00:00
# 22 2011-01-01 22:00:00
# 23 2011-01-01 23:00:00
# 24 2011-01-02 00:00:00

# %%
f = open('tripdata/2010-4th-quarter.csv')
f.next()
# Out:
# 'Duration,Start date,End date,Start station,End station,Bike#,Member Type\n'

# %%
f.next()
# Out:
# '14h 26min. 2sec.,12/31/2010 23:49,1/1/2011 14:15,10th & U St NW (31111),10th & U St NW (31111),W00771,Casual\n'

# %%
temp = f.next().split(',')
temp
# Out:
# ['0h 8min. 34sec.',
#  '12/31/2010 23:37',
#  '12/31/2010 23:46',
#  '10th & U St NW (31111)',
#  '14th & R St NW (31202)',
#  'W01119',
#  'Registered\n']

# %%
from datetime import datetime

# %%
dt = datetime.strptime(temp[1],'%m/%d/%Y %H:%M')
dt
# Out:
# datetime.datetime(2010, 12, 31, 23, 37)

# %%
dt.replace(minute=0)
# Out:
# datetime.datetime(2010, 12, 31, 23, 0)

# %%
import re

# %%
m = re.search('\((.*)\)',temp[3])
m.group(1)
# Out:
# '31111'

# %%
# %run tripdata/transformCapital.py

# %%
filelist = ['tripdata/2011-1st-quarter.csv','tripdata/2011-2nd-quarter.csv','tripdata/2011-3rd-quarter.csv',
            'tripdata/2011-4th-quarter.csv','tripdata/2012-1st-quarter.csv','tripdata/2012-2nd-quarter.csv',
            'tripdata/2012-3rd-quarter.csv','tripdata/2012-4th-quarter.csv']
#filelist = ['tripdata/2012-1st-quarter.csv','tripdata/2012-4th-quarter.csv']
df = loadCapital(filelist)

# %%
# %run insertTemp.py

# %%
scrap = insertTemp(df,'temperature_data.txt')

# %%
scrap.columns.values[-6*24*7:]
# Out:
# array(['w0t40', 'w0t50', 'w0t60', ..., 'w167t70', 'w167t80', 'w167t100'], dtype=object)

# %%
plot(df.temp,df['31111'],'.')

# %%
plot(df.index.hour,df['31111'],'.')

# %%
plot(df.weekhour,df['31111'],'.')

# %%
features = df.columns.values[-6*24*7:]
# Out:
# array(['w0t40', 'w0t50', 'w0t60', ..., 'w167t70', 'w167t80', 'w167t100'], dtype=object)

# %%
X = df[features].values.astype(int)
Y = np.nan_to_num(df['31111'].values)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation
from sklearn import metrics

# %%
models = {}

# %%
for station in df.columns.values[:198]:
    models[station] = LinearRegression(fit_intercept=False).fit(X,np.nan_to_num(df[station].values))

# %%
cross_validation.cross_val_score(models['31111'],X,np.nan_to_num(df['31111'].values),
                                                           cv=3,score_func=metrics.mean_squared_error)
# Out:
# array([ 5.02385249,  5.17357146,  6.46986885])

# %%
cross_vals = {}
for station in df.columns.values[:189]:
    cross_vals[station] = cross_validation.cross_val_score(models[station],X,np.nan_to_num(df[station].values),
                                                           cv=3,score_func=metrics.mean_squared_error)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-49a19475fe61> in <module>()
#       2 for station in df.columns.values[:189]:
#       3     cross_vals[station] = cross_validation.cross_val_score(models[station],X,np.nan_to_num(df[station].values),
# ----> 4                                                            cv=3,score_func=metrics.mean_squared_error)
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, score_func, cv, n_jobs, verbose, fit_params)
#    1132             clone(estimator), X, y, score_func,
#    1133             train, test, verbose, fit_params)
# -> 1134         for train, test in cv)
#    1135     return np.array(scores)
#    1136
#
# ...

# %%
plot(model.coef_[3::6])
plot(model.coef_[0::6],'r')

# %%
plot(models[models.keys()[5]].coef_[1::5])

# %%
24*7
# Out:
# 168

# %%
from sklearn.cluster import KMeans

# %%
kmeanmodel = KMeans(n_clusters=3)

# %%
Xkmean = np.ndarray((198,6*24*7))
for indx,station in enumerate(models.keys()):
    Xkmean[indx] = models[station].coef_

# %%
Xkmean[0].shape
# Out:
# (1008,)

# %%
imgplot = imshow(Xkmean)
imgplot.set_cmap('Greys')

# %%
kmeanmodel.fit(Xkmean)
# Out:
# KMeans(copy_x=True, init='k-means++', k=None, max_iter=300, n_clusters=3,
#     n_init=10, n_jobs=1, precompute_distances=True, random_state=None,
#     tol=0.0001, verbose=0)

# %%
groups = kmeanmodel.predict(Xkmean)

# %%
Xkmean_ordered = np.ndarray((198,6*24*7))
order_indx = 0
for i in xrange(groups.max()+1):
    for line_indx in xrange(len(Xkmean)):
        if groups[line_indx] == i:
            Xkmean_ordered[order_indx] = Xkmean[line_indx]
            order_indx += 1

# %%
imgplot = imshow(Xkmean_ordered)
imgplot.set_cmap('Greys')

# %%
treemodels = {}
df['temp']
subdf = df[np.isfinite(df['temp'])][['temp','weekhour']]

# %%
treeX = subdf.values.astype(float)
treeX.shape
# Out:
# (17311, 2)

# %%
from sklearn.svm import SVR

# %%
svrmodel = SVR()

# %%
svrmodel.fit(treeX,np.nan_to_num(df[np.isfinite(df['temp'])]['31111'].values.astype(float)))
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=False, shrinking=True, tol=0.001,
#   verbose=False)

# %%
j = zip(arange(100),[7]*100)
plot(fabs(svrmodel.predict(j)))

# %%
svrmodels = {}
X = df[np.isfinite(df['temp'])][['temp','weekhour']].values.astype(float)
subrows = np.isfinite(df['temp'])
for station in df.columns.values[:198]:
    Y = np.nan_to_num(df[subrows][station].values.astype(float))
    svrmodels[station] = SVR().fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-180-b2094fc5ddb8> in <module>()
#       3 for station in df.columns.values[:198]:
#       4     Y = np.nan_to_num(df[np.isfinite(df['temp'])][station].values.astype(float))
# ----> 5     svrmodels[station] = SVR().fit(X,Y)
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     189         if self.verbose:  # pragma: no cover
#     190             print '[LibSVM]',
# --> 191         fit(X, y, sample_weight, solver_type, kernel)
#     192
#     193         self.shape_fit_ = X.shape
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/svm/base.pyc in _dense_fit(self, X, y, sample_weight, solver_type, kernel)
# ...

# %%
X = df[np.isfinite(df['temp'])][['temp','weekhour']].values.astype(float)
subrows = np.isfinite(df['temp'])
station = '31111'
Y = np.nan_to_num(df[subrows][station].values.astype(float))
Ycmp = array((Y - Y.min())/(Y.max() - Y.min()))
Ycmp.ravel
#plot(X[:,0],X[:,1],'.',c=Ycmp)
# Out:
# (17311,)
